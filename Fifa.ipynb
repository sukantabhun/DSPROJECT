# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
player_data = pd.read_csv('FIFA22_official_player_data.csv')
player_data.head()
# Out:
#        ID             Name  Age  \
# 0  212198  Bruno Fernandes   26
# 1  209658      L. Goretzka   26
# 2  176580        L. Suárez   34
# 3  192985     K. De Bruyne   30
# 4  224334         M. Acuña   29
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1  https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2  https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3  https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4  https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.com/flags/pt.png       88         89
# 1  https://cdn.sofifa.com/flags/de.png       87         88
# 2  https://cdn.sofifa.com/flags/uy.png       88         88
# 3  https://cdn.sofifa.com/flags/be.png       91         91
# 4  https://cdn.sofifa.com/flags/ar.png       84         84
#
#                  Club                                Club Logo  ...  \
# 0   Manchester United   https://cdn.sofifa.com/teams/11/30.png  ...
# 1   FC Bayern München   https://cdn.sofifa.com/teams/21/30.png  ...
# 2  Atlético de Madrid  https://cdn.sofifa.com/teams/240/30.png  ...
# 3     Manchester City   https://cdn.sofifa.com/teams/10/30.png  ...
# 4          Sevilla FC  https://cdn.sofifa.com/teams/481/30.png  ...
#
#   SlidingTackle GKDiving  GKHandling GKKicking  GKPositioning  GKReflexes  \
# 0          65.0     12.0        14.0      15.0            8.0        14.0
# 1          77.0     13.0         8.0      15.0           11.0         9.0
# 2          38.0     27.0        25.0      31.0           33.0        37.0
# 3          53.0     15.0        13.0       5.0           10.0        13.0
# 4          82.0      8.0        14.0      13.0           13.0        14.0
#
#    Best Position Best Overall Rating Release Clause DefensiveAwareness
# 0            CAM                88.0        €206.9M               72.0
# 1             CM                87.0        €160.4M               74.0
# 2             ST                88.0         €91.2M               42.0
# 3             CM                91.0        €232.2M               68.0
# 4             LB                84.0         €77.7M               80.0
#
# [5 rows x 65 columns]

# %%
player_data.info()
print(player_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16710 entries, 0 to 16709
# Data columns (total 65 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        16710 non-null  int64
#  1   Name                      16710 non-null  object
#  2   Age                       16710 non-null  int64
#  3   Photo                     16710 non-null  object
#  4   Nationality               16710 non-null  object
#  5   Flag                      16710 non-null  object
#  6   Overall                   16710 non-null  int64
#  7   Potential                 16710 non-null  int64
#  8   Club                      16446 non-null  object
#  9   Club Logo                 16710 non-null  object
#  10  Value                     16710 non-null  object
#  11  Wage                      16710 non-null  object
#  12  Special                   16710 non-null  int64
#  13  Preferred Foot            16710 non-null  object
#  14  International Reputation  16710 non-null  float64
#  15  Weak Foot                 16710 non-null  float64
#  16  Skill Moves               16710 non-null  float64
#  17  Work Rate                 16710 non-null  object
#  18  Body Type                 16681 non-null  object
#  19  Real Face                 16681 non-null  object
#  20  Position                  16684 non-null  object
#  21  Jersey Number             16684 non-null  float64
#  22  Joined                    15198 non-null  object
#  23  Loaned From               1132 non-null   object
#  24  Contract Valid Until      16359 non-null  object
#  25  Height                    16710 non-null  object
#  26  Weight                    16710 non-null  object
#  27  Crossing                  16710 non-null  float64
#  28  Finishing                 16710 non-null  float64
#  29  HeadingAccuracy           16710 non-null  float64
#  30  ShortPassing              16710 non-null  float64
#  31  Volleys                   16673 non-null  float64
#  32  Dribbling                 16710 non-null  float64
#  33  Curve                     16673 non-null  float64
#  34  FKAccuracy                16710 non-null  float64
#  35  LongPassing               16710 non-null  float64
#  36  BallControl               16710 non-null  float64
#  37  Acceleration              16710 non-null  float64
#  38  SprintSpeed               16710 non-null  float64
#  39  Agility                   16673 non-null  float64
#  40  Reactions                 16710 non-null  float64
#  41  Balance                   16673 non-null  float64
#  42  ShotPower                 16710 non-null  float64
#  43  Jumping                   16673 non-null  float64
#  44  Stamina                   16710 non-null  float64
#  45  Strength                  16710 non-null  float64
#  46  LongShots                 16710 non-null  float64
#  47  Aggression                16710 non-null  float64
#  48  Interceptions             16702 non-null  float64
#  49  Positioning               16702 non-null  float64
#  50  Vision                    16673 non-null  float64
#  51  Penalties                 16710 non-null  float64
#  52  Composure                 16459 non-null  float64
#  53  Marking                   892 non-null    float64
#  54  StandingTackle            16710 non-null  float64
#  55  SlidingTackle             16673 non-null  float64
#  56  GKDiving                  16710 non-null  float64
#  57  GKHandling                16710 non-null  float64
#  58  GKKicking                 16710 non-null  float64
#  59  GKPositioning             16710 non-null  float64
#  60  GKReflexes                16710 non-null  float64
#  61  Best Position             16710 non-null  object
#  62  Best Overall Rating       16710 non-null  float64
#  63  Release Clause            14961 non-null  object
#  64  DefensiveAwareness        15818 non-null  float64
# dtypes: float64(40), int64(5), object(20)
# memory usage: 8.3+ MB
# (16710, 65)

# %%
team_data = pd.read_csv('FIFA - 2022.csv')
team_data.head()
# Out:
#    Position       Team  Games Played  Win  Draw  Loss  Goals For  \
# 0         1  Argentina             7    6     0     1         15
# 1         2     France             7    5     0     2         16
# 2         3    Croatia             7    4     2     1          8
# 3         4    Morocco             7    4     1     2          6
# 4         5    England             5    3     1     1         13
#
#    Goals Against  Goal Difference  Points
# 0              8                7      18
# 1              8                8      15
# 2              7                1      14
# 3              5                1      13
# 4              4                9      10

# %%
team_data.info()
print(team_data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Position         32 non-null     int64
#  1   Team             32 non-null     object
#  2   Games Played     32 non-null     int64
#  3   Win              32 non-null     int64
#  4   Draw             32 non-null     int64
#  5   Loss             32 non-null     int64
#  6   Goals For        32 non-null     int64
#  7   Goals Against    32 non-null     int64
#  8   Goal Difference  32 non-null     int64
#  9   Points           32 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 2.6+ KB
# (32, 10)

# %%
player_data['Nationality'].unique()
# Out:
# array(['Portugal', 'Germany', 'Uruguay', 'Belgium', 'Argentina', 'Brazil',
#        'Netherlands', 'France', 'Croatia', 'Spain', 'Austria', 'Italy',
#        'Colombia', 'Serbia', 'England', 'Chile', 'Poland', 'Egypt',
#        'Denmark', "Côte d'Ivoire", 'Ukraine', 'Senegal', 'Morocco',
#        'Wales', 'Ecuador', 'Mexico', 'Scotland', 'Ghana',
#        'Czech Republic', 'Peru', 'Algeria', 'United States',
#        'Bosnia and Herzegovina', 'Armenia', 'Korea Republic', 'Russia',
#        'Slovakia', 'Central African Republic', 'Turkey',
#        'North Macedonia', 'Romania', 'Jamaica', 'Canada', 'Nigeria',
#        'Guinea', 'Switzerland', 'Mali', 'China PR', 'Norway', 'Sweden',
#        'Zambia', 'Republic of Ireland', 'Australia', 'Benin', 'Israel',
#        'Gabon', 'Angola', 'Montenegro', 'Paraguay', 'Iraq', 'Slovenia',
#        'Cameroon', 'Iceland', 'Finland', 'Greece', 'Liberia', 'Congo DR',
#        'Venezuela', 'Kosovo', 'Japan', 'Moldova', 'Honduras', 'Tunisia',
#        'Bulgaria', 'Uzbekistan', 'Suriname', 'Curacao', 'Albania',
#        'Hungary', 'Guinea Bissau', 'Costa Rica', 'Northern Ireland',
#        'Fiji', 'Burkina Faso', 'Cape Verde Islands', 'Saudi Arabia',
#        'Iran', 'Comoros', 'Dominican Republic', 'Kenya', 'Panama',
#        'New Zealand', 'South Africa', 'Georgia', 'Zimbabwe', 'Madagascar',
#        'Cyprus', 'Malta', 'Chinese Taipei', 'Syria', 'Mozambique', 'Cuba',
#        'Equatorial Guinea', 'Kazakhstan', 'Congo', 'Burundi', 'Grenada',
#        'Thailand', 'Togo', 'Luxembourg', 'Trinidad and Tobago',
#        'Saint Kitts and Nevis', 'Libya', 'Tanzania', 'Liechtenstein',
#        'United Arab Emirates', 'Gambia', 'Faroe Islands', 'Bermuda',
#        'Sierra Leone', 'Rwanda', 'Chad', 'São Tomé e Príncipe', 'Uganda',
#        'Philippines', 'Palestine', 'Montserrat', 'Bolivia',
#        'Antigua and Barbuda', 'India', 'Lithuania', 'Jordan', 'Belize',
#        'Guyana', 'Azerbaijan', 'Haiti', 'Mauritania', 'Guam', 'Belarus',
#        'El Salvador', 'Puerto Rico', 'Afghanistan', 'Korea DPR', 'Niger',
#        'Namibia', 'Estonia', 'Qatar', 'Eritrea', 'Kyrgyzstan', 'Barbados',
#        'Sudan', 'Malaysia', 'Bhutan', 'Gibraltar', 'Mauritius',
#        'Guatemala', 'New Caledonia', 'Saint Lucia', 'Papua New Guinea',
#        'South Sudan', 'Andorra', 'Hong Kong', 'Lebanon', 'Latvia',
#        'Vietnam', 'Indonesia', 'Macau', 'Oman'], dtype=object)

# %%
l1 = team_data['Team'].tolist()
len(l1)
# Out:
# 32

# %%
player_data = player_data.replace('United States','USA')
player_data = player_data.replace('Korea Republic','South Korea')

# %%
player_data['Nationality'].unique()
# Out:
# array(['Portugal', 'Germany', 'Uruguay', 'Belgium', 'Argentina', 'Brazil',
#        'Netherlands', 'France', 'Croatia', 'Spain', 'Austria', 'Italy',
#        'Colombia', 'Serbia', 'England', 'Chile', 'Poland', 'Egypt',
#        'Denmark', "Côte d'Ivoire", 'Ukraine', 'Senegal', 'Morocco',
#        'Wales', 'Ecuador', 'Mexico', 'Scotland', 'Ghana',
#        'Czech Republic', 'Peru', 'Algeria', 'USA',
#        'Bosnia and Herzegovina', 'Armenia', 'South Korea', 'Russia',
#        'Slovakia', 'Central African Republic', 'Turkey',
#        'North Macedonia', 'Romania', 'Jamaica', 'Canada', 'Nigeria',
#        'Guinea', 'Switzerland', 'Mali', 'China PR', 'Norway', 'Sweden',
#        'Zambia', 'Republic of Ireland', 'Australia', 'Benin', 'Israel',
#        'Gabon', 'Angola', 'Montenegro', 'Paraguay', 'Iraq', 'Slovenia',
#        'Cameroon', 'Iceland', 'Finland', 'Greece', 'Liberia', 'Congo DR',
#        'Venezuela', 'Kosovo', 'Japan', 'Moldova', 'Honduras', 'Tunisia',
#        'Bulgaria', 'Uzbekistan', 'Suriname', 'Curacao', 'Albania',
#        'Hungary', 'Guinea Bissau', 'Costa Rica', 'Northern Ireland',
#        'Fiji', 'Burkina Faso', 'Cape Verde Islands', 'Saudi Arabia',
#        'Iran', 'Comoros', 'Dominican Republic', 'Kenya', 'Panama',
#        'New Zealand', 'South Africa', 'Georgia', 'Zimbabwe', 'Madagascar',
#        'Cyprus', 'Malta', 'Chinese Taipei', 'Syria', 'Mozambique', 'Cuba',
#        'Equatorial Guinea', 'Kazakhstan', 'Congo', 'Burundi', 'Grenada',
#        'Thailand', 'Togo', 'Luxembourg', 'Trinidad and Tobago',
#        'Saint Kitts and Nevis', 'Libya', 'Tanzania', 'Liechtenstein',
#        'United Arab Emirates', 'Gambia', 'Faroe Islands', 'Bermuda',
#        'Sierra Leone', 'Rwanda', 'Chad', 'São Tomé e Príncipe', 'Uganda',
#        'Philippines', 'Palestine', 'Montserrat', 'Bolivia',
#        'Antigua and Barbuda', 'India', 'Lithuania', 'Jordan', 'Belize',
#        'Guyana', 'Azerbaijan', 'Haiti', 'Mauritania', 'Guam', 'Belarus',
#        'El Salvador', 'Puerto Rico', 'Afghanistan', 'Korea DPR', 'Niger',
#        'Namibia', 'Estonia', 'Qatar', 'Eritrea', 'Kyrgyzstan', 'Barbados',
#        'Sudan', 'Malaysia', 'Bhutan', 'Gibraltar', 'Mauritius',
#        'Guatemala', 'New Caledonia', 'Saint Lucia', 'Papua New Guinea',
#        'South Sudan', 'Andorra', 'Hong Kong', 'Lebanon', 'Latvia',
#        'Vietnam', 'Indonesia', 'Macau', 'Oman'], dtype=object)

# %%
player_data_1 = player_data[player_data['Nationality'].isin(l1)]

# %%
player_data_1['Nationality'].unique()
# Out:
# array(['Portugal', 'Germany', 'Uruguay', 'Belgium', 'Argentina', 'Brazil',
#        'Netherlands', 'France', 'Croatia', 'Spain', 'Serbia', 'England',
#        'Poland', 'Denmark', 'Senegal', 'Morocco', 'Wales', 'Ecuador',
#        'Mexico', 'Ghana', 'USA', 'South Korea', 'Canada', 'Switzerland',
#        'Australia', 'Cameroon', 'Japan', 'Tunisia', 'Costa Rica',
#        'Saudi Arabia', 'Iran', 'Qatar'], dtype=object)

# %%
l1
# Out:
# ['Argentina',
#  'France',
#  'Croatia',
#  'Morocco',
#  'England',
#  'Netherlands',
#  'Portugal',
#  'Brazil',
#  'Japan',
#  'Senegal',
#  'Australia',
#  'Switzerland',
#  'USA',
#  'Spain',
#  'Poland',
#  'South Korea',
#  'Germany',
#  'Ecuador',
#  'Cameroon',
#  'Uruguay',
#  'Tunisia',
#  'Mexico',
#  'Belgium',
#  'Ghana',
#  'Saudi Arabia',
#  'Iran',
#  'Costa Rica',
#  'Denmark',
#  'Serbia',
#  'Wales',
#  'Canada',
#  'Qatar']

# %%
l2 = player_data_1['Nationality'].tolist()
l2
# Out:
# ['Portugal',
#  'Germany',
#  'Uruguay',
#  'Belgium',
#  'Argentina',
#  'Germany',
#  'Brazil',
#  'Netherlands',
#  'Germany',
#  'France',
#  'Croatia',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Brazil',
#  'Netherlands',
#  'Spain',
#  'Portugal',
#  'France',
#  'Serbia',
#  'England',
#  'Serbia',
#  'France',
#  'Brazil',
#  'Argentina',
#  'Portugal',
#  'Argentina',
#  'Spain',
#  'Poland',
#  'Spain',
#  'Portugal',
#  'Brazil',
#  'Spain',
#  'England',
#  'Brazil',
#  'Croatia',
#  'Spain',
#  'Spain',
#  'France',
#  'England',
#  'Germany',
#  'Belgium',
#  'Denmark',
#  'Brazil',
#  'England',
#  'Germany',
#  'Senegal',
#  'Denmark',
#  'Morocco',
#  'Belgium',
#  'Portugal',
#  'France',
#  'Spain',
#  'Brazil',
#  'Brazil',
#  'England',
#  'Uruguay',
#  'Germany',
#  'Brazil',
#  'Argentina',
#  'France',
#  'Spain',
#  'Wales',
#  'Spain',
#  'Argentina',
#  'Argentina',
#  'Spain',
#  'Uruguay',
#  'Portugal',
#  'Argentina',
#  'France',
#  'Argentina',
#  'Croatia',
#  'Serbia',
#  'Brazil',
#  'Spain',
#  'Ecuador',
#  'Portugal',
#  'Brazil',
#  'Mexico',
#  'Spain',
#  'France',
#  'Belgium',
#  'Spain',
#  'Brazil',
#  'Ghana',
#  'Argentina',
#  'Brazil',
#  'Germany',
#  'Argentina',
#  'Mexico',
#  'Brazil',
#  'USA',
#  'France',
#  'Croatia',
#  'Brazil',
#  'England',
#  'Spain',
#  'Brazil',
#  'Germany',
#  'France',
#  'Brazil',
#  'Portugal',
#  'Germany',
#  'England',
#  'Portugal',
#  'Germany',
#  'England',
#  'Argentina',
#  'South Korea',
#  'Netherlands',
#  'Netherlands',
#  'England',
#  'Brazil',
#  'Portugal',
#  'Netherlands',
#  'England',
#  'Spain',
#  'Brazil',
#  'Spain',
#  'Brazil',
#  'Brazil',
#  'Germany',
#  'France',
#  'France',
#  'Portugal',
#  'England',
#  'Argentina',
#  'France',
#  'Spain',
#  'Brazil',
#  'Brazil',
#  'Spain',
#  'Brazil',
#  'Croatia',
#  'Spain',
#  'Brazil',
#  'England',
#  'Netherlands',
#  'Spain',
#  'Portugal',
#  'Brazil',
#  'Argentina',
#  'France',
#  'Germany',
#  'Portugal',
#  'Germany',
#  'France',
#  'Croatia',
#  'Spain',
#  'Brazil',
#  'Netherlands',
#  'Spain',
#  'Brazil',
#  'England',
#  'Argentina',
#  'Belgium',
#  'Argentina',
#  'Netherlands',
#  'France',
#  'Brazil',
#  'Spain',
#  'Ghana',
#  'Spain',
#  'France',
#  'Netherlands',
#  'France',
#  'Argentina',
#  'France',
#  'France',
#  'Spain',
#  'England',
#  'France',
#  'Poland',
#  'Canada',
#  'Spain',
#  'Brazil',
#  'Argentina',
#  'Portugal',
#  'Spain',
#  'England',
#  'Germany',
#  'Mexico',
#  'Brazil',
#  'Brazil',
#  'France',
#  'Serbia',
#  'Argentina',
#  'France',
#  'Denmark',
#  'Spain',
#  'Switzerland',
#  'Ghana',
#  'Netherlands',
#  'Portugal',
#  'Spain',
#  'Germany',
#  'Senegal',
#  'Uruguay',
#  'Brazil',
#  'Spain',
#  'Uruguay',
#  'Brazil',
#  'Croatia',
#  'Uruguay',
#  'England',
#  'Brazil',
#  'Brazil',
#  'Uruguay',
#  'England',
#  'Brazil',
#  'Spain',
#  'Netherlands',
#  'Spain',
#  'Argentina',
#  'Germany',
#  'Brazil',
#  'Serbia',
#  'Portugal',
#  'Spain',
#  'France',
#  'England',
#  'Portugal',
#  'England',
#  'France',
#  'Uruguay',
#  'Netherlands',
#  'Belgium',
#  'Brazil',
#  'Serbia',
#  'Spain',
#  'France',
#  'Uruguay',
#  'Mexico',
#  'Denmark',
#  'England',
#  'France',
#  'France',
#  'France',
#  'Croatia',
#  'Portugal',
#  'Brazil',
#  'Belgium',
#  'England',
#  'Belgium',
#  'France',
#  'Senegal',
#  'Brazil',
#  'Argentina',
#  'Argentina',
#  'Spain',
#  'Morocco',
#  'Spain',
#  'Brazil',
#  'Germany',
#  'France',
#  'Ghana',
#  'Spain',
#  'France',
#  'Spain',
#  'Portugal',
#  'Wales',
#  'Spain',
#  'Germany',
#  'Brazil',
#  'Netherlands',
#  'Argentina',
#  'Poland',
#  'Germany',
#  'Uruguay',
#  'Germany',
#  'Argentina',
#  'USA',
#  'Switzerland',
#  'Netherlands',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Ecuador',
#  'Ghana',
#  'England',
#  'Mexico',
#  'Australia',
#  'France',
#  'Belgium',
#  'Netherlands',
#  'Germany',
#  'Brazil',
#  'Germany',
#  'Netherlands',
#  'Uruguay',
#  'Brazil',
#  'Netherlands',
#  'Morocco',
#  'Spain',
#  'Spain',
#  'Netherlands',
#  'Argentina',
#  'Germany',
#  'Argentina',
#  'Spain',
#  'Argentina',
#  'Portugal',
#  'England',
#  'Denmark',
#  'Spain',
#  'Argentina',
#  'Spain',
#  'Argentina',
#  'Brazil',
#  'Brazil',
#  'Uruguay',
#  'Spain',
#  'Uruguay',
#  'Portugal',
#  'Brazil',
#  'Spain',
#  'England',
#  'Switzerland',
#  'Uruguay',
#  'Argentina',
#  'Spain',
#  'Uruguay',
#  'Brazil',
#  'Portugal',
#  'England',
#  'France',
#  'Belgium',
#  'Argentina',
#  'France',
#  'Uruguay',
#  'Brazil',
#  'Spain',
#  'Brazil',
#  'Uruguay',
#  'Spain',
#  'Portugal',
#  'Denmark',
#  'Germany',
#  'Spain',
#  'England',
#  'Brazil',
#  'Argentina',
#  'Poland',
#  'England',
#  'France',
#  'England',
#  'Germany',
#  'Brazil',
#  'France',
#  'Croatia',
#  'Cameroon',
#  'Argentina',
#  'Poland',
#  'Mexico',
#  'Portugal',
#  'Mexico',
#  'Croatia',
#  'Brazil',
#  'Netherlands',
#  'England',
#  'Mexico',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Brazil',
#  'Spain',
#  'Germany',
#  'Switzerland',
#  'England',
#  'Belgium',
#  'England',
#  'Morocco',
#  'Belgium',
#  'Mexico',
#  'Argentina',
#  'France',
#  'France',
#  'France',
#  'Portugal',
#  'Argentina',
#  'Spain',
#  'Argentina',
#  'France',
#  'Spain',
#  'Ghana',
#  'Switzerland',
#  'Uruguay',
#  'Croatia',
#  'Spain',
#  'Spain',
#  'Portugal',
#  'Spain',
#  'France',
#  'France',
#  'France',
#  'Spain',
#  'Brazil',
#  'Portugal',
#  'Spain',
#  'Argentina',
#  'France',
#  'Netherlands',
#  'Argentina',
#  'Brazil',
#  'England',
#  'Croatia',
#  'France',
#  'Argentina',
#  'Brazil',
#  'France',
#  'France',
#  'England',
#  'Argentina',
#  'France',
#  'France',
#  'France',
#  'Germany',
#  'Brazil',
#  'Spain',
#  'Spain',
#  'Argentina',
#  'France',
#  'Netherlands',
#  'Germany',
#  'Netherlands',
#  'Brazil',
#  'Switzerland',
#  'Morocco',
#  'USA',
#  'Spain',
#  'Spain',
#  'Mexico',
#  'Morocco',
#  'France',
#  'Brazil',
#  'Spain',
#  'Germany',
#  'Belgium',
#  'France',
#  'France',
#  'Brazil',
#  'Portugal',
#  'Netherlands',
#  'Uruguay',
#  'Spain',
#  'Brazil',
#  'Belgium',
#  'Brazil',
#  'France',
#  'Uruguay',
#  'Brazil',
#  'Brazil',
#  'Switzerland',
#  'France',
#  'Argentina',
#  'Senegal',
#  'Japan',
#  'Portugal',
#  'Mexico',
#  'France',
#  'USA',
#  'Brazil',
#  'Netherlands',
#  'France',
#  'Cameroon',
#  'France',
#  'Spain',
#  'England',
#  'Brazil',
#  'Spain',
#  'Mexico',
#  'Brazil',
#  'Portugal',
#  'Spain',
#  'Morocco',
#  'Spain',
#  'Serbia',
#  'Mexico',
#  'France',
#  'Spain',
#  'Brazil',
#  'Poland',
#  'Argentina',
#  'Denmark',
#  'Croatia',
#  'Argentina',
#  'Brazil',
#  'Belgium',
#  'Brazil',
#  'Serbia',
#  'France',
#  'Argentina',
#  'Spain',
#  'England',
#  'Serbia',
#  'France',
#  'Morocco',
#  'Portugal',
#  'Spain',
#  'Germany',
#  'Brazil',
#  'Ghana',
#  'Brazil',
#  'Portugal',
#  'Germany',
#  'Japan',
#  'Portugal',
#  'Spain',
#  'Argentina',
#  'Spain',
#  'Brazil',
#  'Tunisia',
#  'Spain',
#  'Brazil',
#  'Netherlands',
#  'Morocco',
#  'Portugal',
#  'Brazil',
#  'Croatia',
#  'England',
#  'England',
#  'Germany',
#  'Brazil',
#  'Portugal',
#  'France',
#  'France',
#  'Croatia',
#  'Argentina',
#  'Germany',
#  'Germany',
#  'Netherlands',
#  'Croatia',
#  'Brazil',
#  'Croatia',
#  'Brazil',
#  'France',
#  'Brazil',
#  'Argentina',
#  'Netherlands',
#  'Ghana',
#  'Spain',
#  'Belgium',
#  'Argentina',
#  'Germany',
#  'Ghana',
#  'Cameroon',
#  'Argentina',
#  'Spain',
#  'Belgium',
#  'Germany',
#  'Spain',
#  'Brazil',
#  'Brazil',
#  'Spain',
#  'Portugal',
#  'Brazil',
#  'France',
#  'Netherlands',
#  'Spain',
#  'Uruguay',
#  'Serbia',
#  'Belgium',
#  'Portugal',
#  'Denmark',
#  'Belgium',
#  'Brazil',
#  'Portugal',
#  'Germany',
#  'Netherlands',
#  'Netherlands',
#  'Germany',
#  'England',
#  'Portugal',
#  'USA',
#  'Portugal',
#  'Spain',
#  'Croatia',
#  'Portugal',
#  'Uruguay',
#  'Spain',
#  'France',
#  'Belgium',
#  'Brazil',
#  'Mexico',
#  'Portugal',
#  'Argentina',
#  'Spain',
#  'France',
#  'England',
#  'France',
#  'Brazil',
#  'Brazil',
#  'Germany',
#  'Argentina',
#  'Belgium',
#  'Switzerland',
#  'France',
#  'Argentina',
#  'Uruguay',
#  'Argentina',
#  'Spain',
#  'Argentina',
#  'England',
#  'Brazil',
#  'France',
#  'Argentina',
#  'Argentina',
#  'Spain',
#  'Belgium',
#  'Spain',
#  'Portugal',
#  'Germany',
#  'Germany',
#  'Spain',
#  'Portugal',
#  'Denmark',
#  'France',
#  'Brazil',
#  'Germany',
#  'Spain',
#  'Brazil',
#  'England',
#  'South Korea',
#  'France',
#  'France',
#  'Spain',
#  'Mexico',
#  'England',
#  'Argentina',
#  'Mexico',
#  'Spain',
#  'Cameroon',
#  'Brazil',
#  'Brazil',
#  'England',
#  'Brazil',
#  'Brazil',
#  'Germany',
#  'Brazil',
#  'Ghana',
#  'Portugal',
#  'Netherlands',
#  'Portugal',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Spain',
#  'Germany',
#  'France',
#  'Wales',
#  'France',
#  'France',
#  'Brazil',
#  'Portugal',
#  'Belgium',
#  'Argentina',
#  'Spain',
#  'Spain',
#  'Netherlands',
#  'Belgium',
#  'Argentina',
#  'Argentina',
#  'Mexico',
#  'Germany',
#  'Germany',
#  'USA',
#  'Portugal',
#  'France',
#  'Costa Rica',
#  'Argentina',
#  'Brazil',
#  'Spain',
#  'Brazil',
#  'Belgium',
#  'Germany',
#  'Germany',
#  'Spain',
#  'Belgium',
#  'France',
#  'Portugal',
#  'Germany',
#  'Portugal',
#  'Spain',
#  'Brazil',
#  'Tunisia',
#  'Spain',
#  'England',
#  'England',
#  'England',
#  'Belgium',
#  'England',
#  'Uruguay',
#  'Japan',
#  'Argentina',
#  'Belgium',
#  'England',
#  'Argentina',
#  'Denmark',
#  'Spain',
#  'Denmark',
#  'Belgium',
#  'France',
#  'Netherlands',
#  'Uruguay',
#  'France',
#  'Argentina',
#  'Germany',
#  'Argentina',
#  'Portugal',
#  'Poland',
#  'Germany',
#  'Denmark',
#  'Germany',
#  'Mexico',
#  'Germany',
#  'France',
#  'Germany',
#  'Netherlands',
#  'Germany',
#  'Argentina',
#  'France',
#  'Australia',
#  'Poland',
#  'Spain',
#  'Netherlands',
#  'Canada',
#  'Germany',
#  'Cameroon',
#  'Switzerland',
#  'Belgium',
#  'Portugal',
#  'Mexico',
#  'Spain',
#  'Switzerland',
#  'Spain',
#  'Uruguay',
#  'Portugal',
#  'Brazil',
#  'Argentina',
#  'France',
#  'France',
#  'Brazil',
#  'Brazil',
#  'Argentina',
#  'Netherlands',
#  'Brazil',
#  'Belgium',
#  'Switzerland',
#  'Brazil',
#  'Argentina',
#  'Germany',
#  'France',
#  'Belgium',
#  'Argentina',
#  'Spain',
#  'USA',
#  'Argentina',
#  'USA',
#  'Uruguay',
#  'Spain',
#  'Brazil',
#  'Netherlands',
#  'Denmark',
#  'England',
#  'Argentina',
#  'Wales',
#  'Senegal',
#  'Brazil',
#  'France',
#  'Argentina',
#  'Brazil',
#  'France',
#  'Japan',
#  'England',
#  'Argentina',
#  'Netherlands',
#  'Spain',
#  'France',
#  'Portugal',
#  'Argentina',
#  'England',
#  'Brazil',
#  'Netherlands',
#  'Germany',
#  'Saudi Arabia',
#  'Spain',
#  'Argentina',
#  'Ecuador',
#  'Spain',
#  'Brazil',
#  'Spain',
#  'Brazil',
#  'Spain',
#  'Brazil',
#  'England',
#  'France',
#  'Spain',
#  'Denmark',
#  'France',
#  'Argentina',
#  'Germany',
#  'Netherlands',
#  'Ghana',
#  'Brazil',
#  'Uruguay',
#  'Switzerland',
#  'France',
#  'Portugal',
#  'Argentina',
#  'Belgium',
#  'Portugal',
#  'Serbia',
#  'Iran',
#  'Ecuador',
#  'Switzerland',
#  'Serbia',
#  'Brazil',
#  'Spain',
#  'Argentina',
#  'France',
#  'Costa Rica',
#  'Spain',
#  'Germany',
#  'Uruguay',
#  'Argentina',
#  'Brazil',
#  'Mexico',
#  'England',
#  'Argentina',
#  'England',
#  'Switzerland',
#  'Portugal',
#  'Spain',
#  'Australia',
#  'Argentina',
#  'Spain',
#  'Germany',
#  'Netherlands',
#  'Argentina',
#  'Argentina',
#  'Brazil',
#  'Argentina',
#  'Denmark',
#  'Belgium',
#  'Brazil',
#  'England',
#  'England',
#  'Brazil',
#  'Serbia',
#  'England',
#  'Netherlands',
#  'Ghana',
#  'Australia',
#  'Spain',
#  'Germany',
#  'Portugal',
#  'Germany',
#  'France',
#  'Brazil',
#  'Brazil',
#  'England',
#  'Argentina',
#  'Spain',
#  'Spain',
#  'Switzerland',
#  'Spain',
#  'USA',
#  'Argentina',
#  'Mexico',
#  'Portugal',
#  'Netherlands',
#  'Spain',
#  'Brazil',
#  'Portugal',
#  'Japan',
#  'Uruguay',
#  'Denmark',
#  'Argentina',
#  'Cameroon',
#  'France',
#  'USA',
#  'France',
#  'Brazil',
#  'France',
#  'France',
#  'Spain',
#  'Senegal',
#  'Mexico',
#  'Brazil',
#  'Argentina',
#  'Brazil',
#  'Spain',
#  'Netherlands',
#  'Ghana',
#  'Spain',
#  'England',
#  'Germany',
#  'Spain',
#  'Ecuador',
#  'USA',
#  'Argentina',
#  'Argentina',
#  'Germany',
#  'England',
#  'France',
#  'Spain',
#  'Argentina',
#  'Canada',
#  'Portugal',
#  'Germany',
#  'Canada',
#  'England',
#  'England',
#  'Saudi Arabia',
#  'Brazil',
#  'Mexico',
#  'England',
#  'France',
#  'Brazil',
#  'Spain',
#  'France',
#  'Portugal',
#  'Portugal',
#  'Serbia',
#  'England',
#  'England',
#  'Spain',
#  'England',
#  'Morocco',
#  'Spain',
#  'Spain',
#  'Argentina',
#  'France',
#  'Morocco',
#  'Mexico',
#  'Netherlands',
#  'Denmark',
#  'Spain',
#  'England',
#  'Mexico',
#  'Brazil',
#  'Netherlands',
#  'Brazil',
#  'France',
#  'Switzerland',
#  'Brazil',
#  'Morocco',
#  'Germany',
#  'France',
#  'Spain',
#  'Brazil',
#  'England',
#  'USA',
#  'Brazil',
#  'Spain',
#  'Spain',
#  'Argentina',
#  'Morocco',
#  'Spain',
#  'Croatia',
#  'Croatia',
#  'South Korea',
#  'Portugal',
#  'Ghana',
#  'Brazil',
#  'Australia',
#  'Argentina',
#  'France',
#  'Brazil',
#  'Serbia',
#  'England',
#  'England',
#  'Brazil',
#  'France',
#  'Argentina',
#  'France',
#  'Spain',
#  'Spain',
#  'Spain',
#  'Croatia',
#  'Netherlands',
#  'England',
#  'Argentina',
#  'Brazil',
#  'Germany',
#  'Saudi Arabia',
#  'Cameroon',
#  'Denmark',
#  'Switzerland',
#  'Argentina',
#  'Serbia',
#  'Brazil',
#  'Serbia',
#  'Netherlands',
#  'England',
#  'Germany',
#  'England',
#  'Croatia',
#  'France',
#  ...]

# %%
team_data['Team'].nunique()
# Out:
# 32

# %%
player_data_1['Nationality'].nunique()
# Out:
# 32

# %%
for i in l1:
    if i not in l2:
        print(i)

# %%
team_data[team_data['Team'] == 'USA']
# Out:
#     Position Team  Games Played  Win  Draw  Loss  Goals For  Goals Against  \
# 12        13  USA             4    1     2     1          3              4
#
#     Goal Difference  Points
# 12               -1       5

# %%
player_data[player_data['Nationality'] == 'South Korea']
# Out:
#            ID            Name  Age  \
# 129    200104          H. Son   28
# 850    199183    Kim Bo Kyung   31
# 1351   200601  Yoon Bit Garam   31
# 1399   184337       Go Yo Han   33
# 1427   218471     Kim Min Woo   31
# ...       ...             ...  ...
# 16144  187144    Cho Soo Hyuk   34
# 16316  238570   Song Bum Keun   23
# 16469  251157  Lee Gwang Yeon   21
# 16648  252658  Baek Jong Beom   20
# 16678  245074  Choi Young Eun   25
#
#                                                   Photo  Nationality  \
# 129    https://cdn.sofifa.com/players/200/104/22_60.png  South Korea
# 850    https://cdn.sofifa.com/players/199/183/22_60.png  South Korea
# 1351   https://cdn.sofifa.com/players/200/601/22_60.png  South Korea
# 1399   https://cdn.sofifa.com/players/184/337/22_60.png  South Korea
# 1427   https://cdn.sofifa.com/players/218/471/22_60.png  South Korea
# ...                                                 ...          ...
# 16144  https://cdn.sofifa.com/players/187/144/22_60.png  South Korea
# 16316  https://cdn.sofifa.com/players/238/570/22_60.png  South Korea
# 16469  https://cdn.sofifa.com/players/251/157/22_60.png  South Korea
# 16648  https://cdn.sofifa.com/players/252/658/22_60.png  South Korea
# 16678  https://cdn.sofifa.com/players/245/074/22_60.png  South Korea
#
#                                       Flag  Overall  Potential  \
# 129    https://cdn.sofifa.com/flags/kr.png       89         89
# 850    https://cdn.sofifa.com/flags/kr.png       72         72
# 1351   https://cdn.sofifa.com/flags/kr.png       73         73
# 1399   https://cdn.sofifa.com/flags/kr.png       70         70
# 1427   https://cdn.sofifa.com/flags/kr.png       69         69
# ...                                    ...      ...        ...
# 16144  https://cdn.sofifa.com/flags/kr.png       60         60
# 16316  https://cdn.sofifa.com/flags/kr.png       67         76
# 16469  https://cdn.sofifa.com/flags/kr.png       60         71
# 16648  https://cdn.sofifa.com/flags/kr.png       51         66
# 16678  https://cdn.sofifa.com/flags/kr.png       58         63
#
#                           Club                                   Club Logo  \
# 129          Tottenham Hotspur      https://cdn.sofifa.com/teams/18/30.png
# 850     Jeonbuk Hyundai Motors    https://cdn.sofifa.com/teams/1477/30.png
# 1351          Ulsan Hyundai FC    https://cdn.sofifa.com/teams/1473/30.png
# 1399                  FC Seoul     https://cdn.sofifa.com/teams/982/30.png
# 1427   Suwon Samsung Bluewings     https://cdn.sofifa.com/teams/983/30.png
# ...                        ...                                         ...
# 16144         Ulsan Hyundai FC    https://cdn.sofifa.com/teams/1473/30.png
# 16316   Jeonbuk Hyundai Motors    https://cdn.sofifa.com/teams/1477/30.png
# 16469               Gangwon FC  https://cdn.sofifa.com/teams/112115/30.png
# 16648                 FC Seoul     https://cdn.sofifa.com/teams/982/30.png
# 16678                 Daegu FC    https://cdn.sofifa.com/teams/2056/30.png
#
#        ... SlidingTackle GKDiving  GKHandling GKKicking  GKPositioning  \
# 129    ...          33.0     11.0        13.0      13.0            6.0
# 850    ...          55.0     12.0        15.0      10.0           13.0
# 1351   ...          49.0      8.0        11.0      11.0           11.0
# 1399   ...          61.0     11.0        12.0      13.0           16.0
# 1427   ...          62.0     11.0         6.0      14.0           16.0
# ...    ...           ...      ...         ...       ...            ...
# 16144  ...          15.0     60.0        61.0      60.0           60.0
# 16316  ...          12.0     68.0        64.0      65.0           67.0
# 16469  ...          12.0     60.0        60.0      54.0           63.0
# 16648  ...          13.0     49.0        50.0      51.0           48.0
# 16678  ...          14.0     58.0        58.0      47.0           54.0
#
#        GKReflexes  Best Position Best Overall Rating Release Clause  \
# 129          10.0             LM                89.0        €197.6M
# 850          13.0            CAM                74.0          €2.5M
# 1351          6.0             CM                73.0          €3.3M
# 1399         15.0             RM                70.0          €1.3M
# 1427         10.0            CAM                70.0          €1.4M
# ...           ...            ...                 ...            ...
# 16144        58.0             GK                60.0           €52K
# 16316        68.0             GK                67.0            €3M
# 16469        61.0             GK                60.0          €689K
# 16648        55.0             GK                51.0          €225K
# 16678        61.0             GK                58.0          €318K
#
#       DefensiveAwareness
# 129                 50.0
# 850                 59.0
# 1351                58.0
# 1399                60.0
# 1427                49.0
# ...                  ...
# 16144               28.0
# 16316               23.0
# 16469                8.0
# 16648               10.0
# 16678                7.0
#
# [177 rows x 65 columns]

# %%
Team_Score = pd.DataFrame(columns=['Team_Name','Win_Loss_perc','Player_Score','Net_Score'])

# %%
def Win_Loss_perc(team):
    data = team_data[team_data['Team'] == team]
    score = data['Win']*3 +data['Draw']*1
    score = score /(data['Games Played']*3)
    score = score * 50
    return score.iloc[0]

# %%
def Player_Score(team):
    data = player_data_1[player_data_1['Nationality']==team]
    data = data.loc[:,'Crossing':'DefensiveAwareness'].select_dtypes(exclude = 'object')
    score = 0
    for index, row in data.iterrows():
        player_score = row.sum()
        score = score + (player_score/3400)
    score = score / data.shape[0]
    return round(score * 50,2)

# %%
for index ,row in team_data.iterrows():
    wl = Win_Loss_perc(row['Team'])
    ps = Player_Score(row['Team'])
    net_score = (wl + ps)
    new_entry = {'Team_Name':row['Team'],'Win_Loss_perc':wl,'Player_Score':ps,'Net_Score':net_score}
    Team_Score.loc[index] = new_entry
Team_Score
# Out:
#        Team_Name  Win_Loss_perc  Player_Score  Net_Score
# 0      Argentina      42.857143         27.38  70.237143
# 1         France      35.714286         26.49  62.204286
# 2        Croatia      33.333333         26.36  59.693333
# 3        Morocco      30.952381         27.75  58.702381
# 4        England      33.333333         25.14  58.473333
# 5    Netherlands      33.333333         26.38  59.713333
# 6       Portugal      30.000000         27.30  57.300000
# 7         Brazil      30.000000         27.78  57.780000
# 8          Japan      25.000000         26.20  51.200000
# 9        Senegal      25.000000         26.46  51.460000
# 10     Australia      25.000000         25.08  50.080000
# 11   Switzerland      25.000000         26.01  51.010000
# 12           USA      20.833333         24.91  45.743333
# 13         Spain      16.666667         26.88  43.546667
# 14        Poland      16.666667         25.49  42.156667
# 15   South Korea      16.666667         25.68  42.346667
# 16       Germany      22.222222         25.31  47.532222
# 17       Ecuador      22.222222         25.97  48.192222
# 18      Cameroon      22.222222         26.48  48.702222
# 19       Uruguay      22.222222         26.83  49.052222
# 20       Tunisia      22.222222         27.08  49.302222
# 21        Mexico      22.222222         26.05  48.272222
# 22       Belgium      22.222222         26.82  49.042222
# 23         Ghana      16.666667         27.22  43.886667
# 24  Saudi Arabia      16.666667         25.37  42.036667
# 25          Iran      16.666667         27.05  43.716667
# 26    Costa Rica      16.666667         26.93  43.596667
# 27       Denmark       5.555556         26.18  31.735556
# 28        Serbia       5.555556         27.01  32.565556
# 29         Wales       5.555556         25.41  30.965556
# 30        Canada       0.000000         24.72  24.720000
# 31         Qatar       0.000000         26.81  26.810000

# %%
df = Team_Score.head(5)

# %%
plt.bar(df['Team_Name'],df['Net_Score'],width=0.2,color='cyan',label = 'Total Team Score (max : 100)')
plt.bar(df['Team_Name'],df['Player_Score'],width=0.2,color='brown',label = 'All Team Player Stats basisScore (max : 50)')
plt.bar(df['Team_Name'],df['Win_Loss_perc'],width=0.2,color='red',label = 'Team Win,Loss and Draw Score (max : 50)')
plt.legend()
plt.xlabel('Teams')
plt.ylabel('Scores')
plt.title('Score ranking of Team on the basis of Player Stats and Teams Win-Loss Ratio')
plt.plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       3 plt.bar(df['Team_Name'],df['Win_Loss_perc'],width=0.2,color='red',label = 'Team Win,Loss and Draw Score (max : 50)')
#       4 plt.legend()
# ----> 5 plt.xticks(x-0.2,x,x+0.2)
#       6 plt.xlabel('Teams')
#       7 plt.ylabel('Scores')
#
# NameError: name 'x' is not defined

# %%
plt.style.use('ggplot')


x = range(len(df['Team_Name']))

plt.figure(figsize = (20,12))
plt.bar(x, df['Net_Score'], width=0.2, color='cyan', align='center', label='Total Team Score (max : 100)')
plt.bar([i + 0.2 for i in x], df['Player_Score'], width=0.2, color='brown', align='center', label='All Team Player Stats basis Score (max : 50)')
plt.bar([i + 0.4 for i in x], df['Win_Loss_perc'], width=0.2, color='red', align='center', label='Team Win, Loss, and Draw Score (max : 50)')

plt.xlabel('Teams',fontsize=40)
plt.ylabel('Scores',fontsize=40)
plt.title('Score ranking of Team on the basis of Player Stats and Teams Win-Loss Ratio',fontsize=40)
plt.xticks([i + 0.2 for i in x], df['Team_Name'],fontsize=20)
plt.yticks(fontsize=20)
plt.legend(fontsize = 15)
plt.show()
data1 = df.head(1)
print('As seen in the Graph which is based Stats of all Team Players and the past win loss ratio of all the teams\n The team that is predicted to win is',data1.loc[0,'Team_Name'])
# Out:
# As seen in the Graph which is based Stats of all Team Players and the past win loss ratio of all the teams
#  The team that is predicted to win is Argentina
